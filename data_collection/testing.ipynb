# %%
# Standard imports
import numpy as np
import pandas as pd

# For web scraping
import requests
from bs4 import BeautifulSoup

# For performing regex operations
import re

import os
import datetime

from limitless_scrape import *
from limitless_analysis import *

# %%
# Get URL of most recent tournament
df_latenight = scrape_for_dates_and_url()
t_url = [df_latenight.iloc[0]['URL']]

# %%
# Create urls for this tourmanent
url_dict = create_urls(t_url)

# %%
# 6. Scrape urls in dict and add date
scrape_results_dict = multi_latenight_scrape(url_dict)
scrape_results_dict = add_date_to_dict(scrape_results_dict, df_latenight)
# Out:
# INFO:root:Scraping players table for https://play.limitlesstcg.com/tournament/ln68/standings

# %%
# Display Standings 
players_df = scrape_results_dict['https://play.limitlesstcg.com/tournament/ln68/']['players']
players_df.head()
# Out:
#   Place                         Name Country Points      Record Opp. Win %  \
# 0     1  Juancho (PrimeTimeWizardTV)             40  13 - 3 - 1
# 1     2              Alongwaytobepro             38  12 - 3 - 2
# 2     3                     Sanjay7s             40  13 - 2 - 1
# 3     4                     UltraNko             34  11 - 4 - 1
# 4     5            David Hendrickson             34  11 - 3 - 1
#
#   Opp. Opp. %             Deck List        Player ID
# 0                Arceus Goodra               auriz27
# 1                        Regis       alongwaytobepro
# 2                Lost Zone Box              sanjay7s
# 3              Giratina LZ Box              ultranko
# 4              Palkia Inteleon            royalcheez

# %%
# Display Pairings 
round_dict = scrape_results_dict['https://play.limitlesstcg.com/tournament/ln68/']['pairings']['round_1_dict']
round1_df = scrape_results_dict['https://play.limitlesstcg.com/tournament/ln68/']['pairings']['round_1_dict']['df']
round1_df.head()
# Out:
#   Pairing             Player 1 Player 1 Score Player 2 Score  \
# 0       1         Timm1011-0-0              0              0
# 1       2  mryeet123412340-1-0              0              0
# 2       3     Taylor Metz0-1-0              0              0
# 3       4        grantm121-0-0              1              0
# 4       5       compYammu0-1-0              0              1
#
#                 Player 2   Player 1 Name     Player 2 Name Player 1 Record  \
# 0       inosoycarly0-1-0         Timm101       inosoycarly           1-0-0
# 1  Orion Sutherland1-0-0  mryeet12341234  Orion Sutherland           0-1-0
# 2           Mwaubin1-0-0     Taylor Metz           Mwaubin           0-1-0
# 3        amcharles10-1-0        grantm12        amcharles1           1-0-0
# 4   Terryharris78991-0-0       compYammu   Terryharris7899           0-1-0
#
#   Player 2 Record           Winner ID     Player 1 ID         Player 2 ID
# 0           0-1-0             timm101         timm101         inosoycarly
# 1           1-0-0  joshuasutherland21  mryeet12341234  joshuasutherland21
# 2           1-0-0             mwaubin           zoura             mwaubin
# 3           0-1-0            grantm12        grantm12          amcharles1
# 4           1-0-0     terryharris7899       compyammu     terryharris7899

# %%
deck_and_records(round_dict, players_df).head()
# Out:
#   Pairing          Player 1 Player 1 Score Player 2 Score         Player 2  \
# 0       1   Hisuian Zoroark              0              0            Regis
# 1       2  Calyrex Inteleon              0              0           Arceus
# 2       3     Kyurem Palkia              0              0          Blissey
# 3       4     Kyurem Palkia              1              0  Hisuian Zoroark
# 4       5   Arceus Giratina              0              1    Arceus Goodra
#
#     Player 1 Name     Player 2 Name Player 1 Record Player 2 Record  \
# 0         Timm101       inosoycarly           1-0-0           0-1-0
# 1  mryeet12341234  Orion Sutherland           0-1-0           1-0-0
# 2     Taylor Metz           Mwaubin           0-1-0           1-0-0
# 3        grantm12        amcharles1           1-0-0           0-1-0
# 4       compYammu   Terryharris7899           0-1-0           1-0-0
#
#             Winner ID     Player 1 ID         Player 2 ID     Player 1 Deck  \
# 0             timm101         timm101         inosoycarly   Hisuian Zoroark
# 1  joshuasutherland21  mryeet12341234  joshuasutherland21  Calyrex Inteleon
# 2             mwaubin           zoura             mwaubin     Kyurem Palkia
# 3            grantm12        grantm12          amcharles1     Kyurem Palkia
# 4     terryharris7899       compyammu     terryharris7899   Arceus Giratina
#
#      Player 2 Deck     Winning Deck
# 0            Regis  Hisuian Zoroark
# 1           Arceus           Arceus
# 2          Blissey          Blissey
# 3  Hisuian Zoroark    Kyurem Palkia
# 4    Arceus Goodra    Arceus Goodra

# %%
# 7. Process data: Get WLT counts for each deck in each tournament
all_tournament_results_dict = multi_tournament_wr_per_tournament(scrape_results_dict)

# Calculate winrates
multi_tournament_wr_calc(all_tournament_results_dict)

# Create plot_df
plot_df = create_plot_df(all_tournament_results_dict)

# %%
# Attempt to make heatmap
groupby_df = plot_df.groupby(['deck', 'opposing_deck']).agg({"winrate": "mean", "games_played": "sum"}).reset_index()

# %%
# All archetypes in 'deck' columns
all_archetypes = [x for x in groupby_df['deck'].unique()]

# Add archetypes in 'opposing_deck'
opp_decks = [x for x in groupby_df['opposing_deck'].unique()]

for deck in [archetype for archetype in opp_decks if archetype not in all_archetypes]:
    all_archetypes.append(deck)

# %%
# Create heatmap_df
heatmap_df = pd.DataFrame(columns=all_archetypes, index=all_archetypes)

# %%
for deck in heatmap_df:
    # get win rate 
    filtered_df = groupby_df[groupby_df['deck'] == deck]
# Out:
# Arcanine Zoroark
# Arceus
# Arceus Duraludon
# Arceus Flying Pikachu
# Arceus Giratina
# Arceus Goodra
# Arceus Mewtwo
# Arceus Rayquaza
# Blissey
# Calyrex Inteleon
# Charizard
# Cramorant
# Crobat Weezing
# Dialga
# Dialga Bronzong
# Dialga LZ
# Durant
# Eternatus
# Flaaffy
# Galarian Weezing
# Gengar
# Giratina LZ Box
# Hisuian Goodra
# Hisuian Samurott
# Hisuian Zoroark
# Ice Rider Calyrex
# Inteleon Box
# Kyurem
# Kyurem Palkia
# Lost Zone Box
# Lunatone Solrock
# Machamp
# Mew Genesect
# Other
# Palkia Inteleon
# Rapid Strike Urshifu
# Regis
# Shadow Rider Calyrex
# Suicune Inteleon
# Urshifu Inteleon
# Vikavolt
# Volcarona
# Zeraora

# %%
filtered_df = groupby_df[groupby_df['deck'] == "Palkia Inteleon"]

# %%
filtered_df
# Out:
#                 deck          opposing_deck  winrate  games_played
# 368  Palkia Inteleon       Arcanine Zoroark     0.00             3
# 369  Palkia Inteleon                 Arceus     0.75             4
# 370  Palkia Inteleon       Arceus Duraludon     0.50             2
# 371  Palkia Inteleon  Arceus Flying Pikachu     0.00             1
# 372  Palkia Inteleon        Arceus Giratina     1.00             2
# 373  Palkia Inteleon          Arceus Goodra     0.40            15
# 374  Palkia Inteleon          Arceus Mewtwo     1.00             1
# 375  Palkia Inteleon                Blissey     0.12             8
# 376  Palkia Inteleon         Crobat Weezing     1.00             1
# 377  Palkia Inteleon                 Dialga     0.25             4
# 378  Palkia Inteleon        Dialga Bronzong     1.00             1
# 379  Palkia Inteleon              Dialga LZ     0.29             7
# 380  Palkia Inteleon                 Durant     0.50             2
# 381  Palkia Inteleon              Eternatus     0.75             4
# 382  Palkia Inteleon                 Gengar     1.00             1
# 383  Palkia Inteleon        Giratina LZ Box     0.50            38
# 384  Palkia Inteleon         Hisuian Goodra     0.75             4
# 385  Palkia Inteleon        Hisuian Zoroark     0.60            10
# 386  Palkia Inteleon                 Kyurem     1.00             1
# 387  Palkia Inteleon          Kyurem Palkia     0.90            10
# 388  Palkia Inteleon          Lost Zone Box     0.43            14
# 389  Palkia Inteleon       Lunatone Solrock     1.00             1
# 390  Palkia Inteleon           Mew Genesect     0.50            18
# 391  Palkia Inteleon                  Other     1.00             1
# 392  Palkia Inteleon        Palkia Inteleon     0.47            34
# 393  Palkia Inteleon   Rapid Strike Urshifu     1.00             1
# 394  Palkia Inteleon                  Regis     0.50            20
# 395  Palkia Inteleon   Shadow Rider Calyrex     0.33             3
# 396  Palkia Inteleon       Suicune Inteleon     1.00             2
# 397  Palkia Inteleon       Urshifu Inteleon     1.00             1
# 398  Palkia Inteleon               Vikavolt     0.60             5
# 399  Palkia Inteleon              Volcarona     0.00             1

# %%
# Iterate through each active deck
for active_deck in heatmap_df:
    filtered_df = groupby_df[groupby_df['deck']==active_deck]
    
    # Find win rate for every deck in index (opposing deck)
    mu = []
    for deck in heatmap_df.index:
        if deck in filtered_df['opposing_deck'].unique():
            winrate = filtered_df[filtered_df['opposing_deck']==deck].iloc[0]['winrate']
            mu.append(winrate)
        else:
            winrate = None
            mu.append(winrate)
        
    # set column to mu 
    heatmap_df[active_deck] = mu

# %%
heatmap_df
# Out:
#                        Arcanine Zoroark  Arceus  Arceus Duraludon  \
# Arcanine Zoroark                    NaN     NaN               NaN
# Arceus                              NaN    0.50               NaN
# Arceus Duraludon                    NaN     NaN               NaN
# Arceus Flying Pikachu               NaN     NaN               NaN
# Arceus Giratina                     NaN    1.00               NaN
# Arceus Goodra                       NaN    0.50              0.67
# Arceus Mewtwo                       NaN     NaN               NaN
# Arceus Rayquaza                     NaN     NaN               NaN
# Blissey                            1.00    0.00              0.67
# Calyrex Inteleon                    NaN    1.00               NaN
# Charizard                           NaN    1.00               NaN
# Cramorant                           NaN     NaN               NaN
# Crobat Weezing                      NaN     NaN               NaN
# Dialga                              NaN     NaN               NaN
# Dialga Bronzong                     NaN    0.00               NaN
# Dialga LZ                          1.00    1.00              0.00
# Durant                              NaN     NaN               NaN
# Eternatus                           NaN     NaN               NaN
# Flaaffy                             NaN     NaN               NaN
# Galarian Weezing                    NaN     NaN               NaN
# Gengar                              NaN     NaN               NaN
# Giratina LZ Box                    0.00    0.60              0.40
# Hisuian Goodra                      NaN    0.00               NaN
# Hisuian Samurott                    NaN     NaN               NaN
# Hisuian Zoroark                    1.00    0.00               NaN
# Ice Rider Calyrex                   NaN     NaN               NaN
# Inteleon Box                        NaN     NaN               NaN
# Kyurem                              NaN     NaN               NaN
# Kyurem Palkia                      0.00    0.00              0.00
# Lost Zone Box                      0.50    0.40               NaN
# Lunatone Solrock                    NaN     NaN               NaN
# Machamp                             NaN     NaN              1.00
# Mew Genesect                       1.00    0.67              0.00
# Other                               NaN     NaN              1.00
# Palkia Inteleon                    0.33    0.25              0.50
# Rapid Strike Urshifu                NaN     NaN               NaN
# Regis                              1.00    0.33              0.00
# Shadow Rider Calyrex                NaN     NaN              0.00
# Suicune Inteleon                    NaN     NaN               NaN
# Urshifu Inteleon                    NaN     NaN               NaN
# Vikavolt                            NaN     NaN              0.00
# Volcarona                           NaN     NaN               NaN
# Zeraora                             NaN     NaN               NaN
#
#                        Arceus Flying Pikachu  Arceus Giratina  Arceus Goodra  \
# Arcanine Zoroark                         NaN              NaN            NaN
# Arceus                                   NaN             0.00           0.50
# Arceus Duraludon                         NaN              NaN           0.00
# Arceus Flying Pikachu                    NaN              NaN           0.67
# Arceus Giratina                          NaN              NaN           1.00
# Arceus Goodra                            0.0             0.00           0.40
# Arceus Mewtwo                            NaN              NaN           0.00
# Arceus Rayquaza                          NaN             1.00            NaN
# Blissey                                  NaN             0.67           0.10
# Calyrex Inteleon                         NaN              NaN           0.50
# Charizard                                NaN             0.00            NaN
# Cramorant                                NaN              NaN            NaN
# Crobat Weezing                           NaN              NaN           1.00
# Dialga                                   NaN              NaN            NaN
# Dialga Bronzong                          NaN             0.00            NaN
# Dialga LZ                                NaN             0.00           0.00
# Durant                                   NaN              NaN           1.00
# Eternatus                                NaN              NaN            NaN
# Flaaffy                                  NaN              NaN            NaN
# Galarian Weezing                         NaN              NaN            NaN
# Gengar                                   NaN              NaN            NaN
# Giratina LZ Box                          NaN             0.73           0.53
# Hisuian Goodra                           NaN             0.50           0.33
# Hisuian Samurott                         NaN              NaN           1.00
# Hisuian Zoroark                          NaN             0.20           0.50
# Ice Rider Calyrex                        NaN              NaN            NaN
# Inteleon Box                             NaN              NaN            NaN
# Kyurem                                   NaN              NaN            NaN
# Kyurem Palkia                            NaN             0.67           0.38
# Lost Zone Box                            NaN             0.71           0.53
# Lunatone Solrock                         NaN              NaN            NaN
# Machamp                                  NaN              NaN           1.00
# Mew Genesect                             NaN             0.11           0.44
# Other                                    0.0             0.00           0.67
# Palkia Inteleon                          0.0             0.00           0.60
# Rapid Strike Urshifu                     NaN              NaN            NaN
# Regis                                    0.0             0.88           0.60
# Shadow Rider Calyrex                     NaN              NaN           0.25
# Suicune Inteleon                         NaN              NaN            NaN
# Urshifu Inteleon                         NaN              NaN            NaN
# Vikavolt                                 NaN             1.00           0.00
# Volcarona                                NaN              NaN           0.50
# Zeraora                                  NaN              NaN            NaN
#
#                        Arceus Mewtwo  Arceus Rayquaza  Blissey  \
# Arcanine Zoroark                 NaN              NaN     0.00
# Arceus                           NaN              NaN     0.67
# Arceus Duraludon                 NaN              NaN     0.00
# Arceus Flying Pikachu            NaN              NaN      NaN
# Arceus Giratina                  NaN              0.0     0.33
# Arceus Goodra                   1.00              NaN     0.50
# Arceus Mewtwo                    NaN              NaN     0.67
# Arceus Rayquaza                  NaN              NaN     0.00
# Blissey                         0.33              1.0     0.50
# Calyrex Inteleon                 NaN              NaN      NaN
# Charizard                        NaN              NaN      NaN
# Cramorant                        NaN              NaN      NaN
# Crobat Weezing                   NaN              NaN     1.00
# Dialga                           NaN              NaN      NaN
# Dialga Bronzong                  NaN              NaN     0.00
# Dialga LZ                        NaN              NaN     1.00
# Durant                           NaN              NaN     0.00
# Eternatus                        NaN              NaN      NaN
# Flaaffy                          NaN              NaN      NaN
# Galarian Weezing                 NaN              NaN      NaN
# Gengar                           NaN              NaN      NaN
# Giratina LZ Box                  NaN              1.0     0.44
# Hisuian Goodra                   NaN              NaN      NaN
# Hisuian Samurott                 NaN              NaN      NaN
# Hisuian Zoroark                  NaN              NaN     0.75
# Ice Rider Calyrex                NaN              NaN      NaN
# Inteleon Box                     NaN              NaN      NaN
# Kyurem                           NaN              NaN      NaN
# Kyurem Palkia                   0.00              0.0     0.64
# Lost Zone Box                   0.00              1.0     0.43
# Lunatone Solrock                 NaN              NaN      NaN
# Machamp                          NaN              NaN      NaN
# Mew Genesect                    0.50              1.0     0.40
# Other                            NaN              NaN     1.00
# Palkia Inteleon                 0.00              NaN     0.75
# Rapid Strike Urshifu             NaN              NaN      NaN
# Regis                            NaN              0.0     0.33
# Shadow Rider Calyrex             NaN              NaN     0.00
# Suicune Inteleon                 NaN              NaN      NaN
# Urshifu Inteleon                 NaN              NaN      NaN
# Vikavolt                         NaN              NaN      NaN
# Volcarona                        NaN              NaN      NaN
# Zeraora                          NaN              NaN      NaN
#
#                        Calyrex Inteleon  ...  Other  Palkia Inteleon  \
# Arcanine Zoroark                    NaN  ...    NaN             0.00
# Arceus                              0.0  ...    NaN             0.75
# Arceus Duraludon                    NaN  ...   0.00             0.50
# Arceus Flying Pikachu               NaN  ...   0.00             0.00
# Arceus Giratina                     NaN  ...   0.00             1.00
# Arceus Goodra                       0.0  ...   0.33             0.40
# Arceus Mewtwo                       NaN  ...    NaN             1.00
# Arceus Rayquaza                     NaN  ...    NaN              NaN
# Blissey                             NaN  ...   0.00             0.12
# Calyrex Inteleon                    NaN  ...   0.00              NaN
# Charizard                           NaN  ...    NaN              NaN
# Cramorant                           NaN  ...    NaN              NaN
# Crobat Weezing                      NaN  ...    NaN             1.00
# Dialga                              NaN  ...    NaN             0.25
# Dialga Bronzong                     NaN  ...   0.00             1.00
# Dialga LZ                           0.0  ...    NaN             0.29
# Durant                              1.0  ...    NaN             0.50
# Eternatus                           NaN  ...    NaN             0.75
# Flaaffy                             NaN  ...    NaN              NaN
# Galarian Weezing                    NaN  ...    NaN              NaN
# Gengar                              NaN  ...    NaN             1.00
# Giratina LZ Box                     NaN  ...   0.33             0.50
# Hisuian Goodra                      NaN  ...    NaN             0.75
# Hisuian Samurott                    NaN  ...    NaN              NaN
# Hisuian Zoroark                     NaN  ...   0.67             0.60
# Ice Rider Calyrex                   NaN  ...    NaN              NaN
# Inteleon Box                        NaN  ...    NaN              NaN
# Kyurem                              0.0  ...   1.00             1.00
# Kyurem Palkia                       0.5  ...   0.50             0.90
# Lost Zone Box                       NaN  ...   0.00             0.43
# Lunatone Solrock                    NaN  ...    NaN             1.00
# Machamp                             NaN  ...    NaN              NaN
# Mew Genesect                        0.5  ...   0.50             0.50
# Other                               1.0  ...    NaN             1.00
# Palkia Inteleon                     NaN  ...   0.00             0.47
# Rapid Strike Urshifu                NaN  ...    NaN             1.00
# Regis                               NaN  ...   0.00             0.50
# Shadow Rider Calyrex                NaN  ...    NaN             0.33
# Suicune Inteleon                    NaN  ...   0.00             1.00
# Urshifu Inteleon                    NaN  ...    NaN             1.00
# Vikavolt                            NaN  ...    NaN             0.60
# Volcarona                           NaN  ...    NaN             0.00
# Zeraora                             NaN  ...    NaN              NaN
#
#                        Rapid Strike Urshifu  Regis  Shadow Rider Calyrex  \
# Arcanine Zoroark                        NaN   0.00                   NaN
# Arceus                                  NaN   0.33                   NaN
# Arceus Duraludon                        NaN   1.00                  1.00
# Arceus Flying Pikachu                   NaN   1.00                   NaN
# Arceus Giratina                         NaN   0.12                   NaN
# Arceus Goodra                           NaN   0.30                  0.75
# Arceus Mewtwo                           NaN    NaN                   NaN
# Arceus Rayquaza                         NaN   1.00                   NaN
# Blissey                                 NaN   0.67                  1.00
# Calyrex Inteleon                        NaN    NaN                   NaN
# Charizard                               NaN   0.00                   NaN
# Cramorant                               NaN   1.00                   NaN
# Crobat Weezing                          NaN    NaN                   NaN
# Dialga                                  NaN    NaN                   NaN
# Dialga Bronzong                         NaN    NaN                   NaN
# Dialga LZ                               NaN   0.67                  1.00
# Durant                                  NaN    NaN                   NaN
# Eternatus                               NaN    NaN                   NaN
# Flaaffy                                 NaN    NaN                   NaN
# Galarian Weezing                        NaN    NaN                   NaN
# Gengar                                  NaN   1.00                   NaN
# Giratina LZ Box                         NaN   0.45                  0.57
# Hisuian Goodra                          NaN   0.50                   NaN
# Hisuian Samurott                        NaN    NaN                   NaN
# Hisuian Zoroark                         NaN   0.33                  0.00
# Ice Rider Calyrex                       NaN    NaN                   NaN
# Inteleon Box                            NaN   1.00                   NaN
# Kyurem                                  NaN    NaN                   NaN
# Kyurem Palkia                           NaN   0.10                  0.50
# Lost Zone Box                           NaN   0.39                  0.50
# Lunatone Solrock                        NaN    NaN                   NaN
# Machamp                                 NaN    NaN                   NaN
# Mew Genesect                            NaN   0.47                  0.00
# Other                                   NaN   1.00                   NaN
# Palkia Inteleon                         0.0   0.40                  0.67
# Rapid Strike Urshifu                    NaN    NaN                   NaN
# Regis                                   NaN   0.50                  0.50
# Shadow Rider Calyrex                    NaN   0.00                   NaN
# Suicune Inteleon                        NaN    NaN                   NaN
# Urshifu Inteleon                        NaN    NaN                   NaN
# Vikavolt                                NaN   0.60                   NaN
# Volcarona                               NaN    NaN                   NaN
# Zeraora                                 NaN    NaN                   NaN
#
#                        Suicune Inteleon  Urshifu Inteleon  Vikavolt  \
# Arcanine Zoroark                    NaN               NaN       NaN
# Arceus                              NaN               NaN       NaN
# Arceus Duraludon                    NaN               NaN       1.0
# Arceus Flying Pikachu               NaN               NaN       NaN
# Arceus Giratina                     NaN               NaN       0.0
# Arceus Goodra                       NaN               NaN       1.0
# Arceus Mewtwo                       NaN               NaN       NaN
# Arceus Rayquaza                     NaN               NaN       NaN
# Blissey                             NaN               NaN       NaN
# Calyrex Inteleon                    NaN               NaN       NaN
# Charizard                           NaN               NaN       NaN
# Cramorant                           NaN               NaN       NaN
# Crobat Weezing                      NaN               NaN       NaN
# Dialga                              NaN               NaN       NaN
# Dialga Bronzong                     NaN               NaN       NaN
# Dialga LZ                           NaN               NaN       NaN
# Durant                              NaN               NaN       NaN
# Eternatus                           NaN               NaN       NaN
# Flaaffy                             NaN               NaN       NaN
# Galarian Weezing                    NaN               NaN       NaN
# Gengar                              NaN               NaN       1.0
# Giratina LZ Box                     NaN               1.0       0.5
# Hisuian Goodra                      NaN               NaN       0.0
# Hisuian Samurott                    NaN               NaN       NaN
# Hisuian Zoroark                     NaN               1.0       0.5
# Ice Rider Calyrex                   NaN               NaN       NaN
# Inteleon Box                        NaN               NaN       NaN
# Kyurem                              NaN               NaN       NaN
# Kyurem Palkia                       NaN               NaN       NaN
# Lost Zone Box                       0.0               0.0       1.0
# Lunatone Solrock                    NaN               NaN       NaN
# Machamp                             NaN               NaN       NaN
# Mew Genesect                        NaN               0.0       0.0
# Other                               1.0               NaN       NaN
# Palkia Inteleon                     0.0               0.0       0.4
# Rapid Strike Urshifu                NaN               NaN       NaN
# Regis                               NaN               NaN       0.4
# Shadow Rider Calyrex                NaN               NaN       NaN
# Suicune Inteleon                    NaN               NaN       NaN
# Urshifu Inteleon                    NaN               NaN       NaN
# Vikavolt                            NaN               NaN       NaN
# Volcarona                           NaN               NaN       NaN
# Zeraora                             NaN               NaN       NaN
#
#                        Volcarona  Zeraora
# Arcanine Zoroark             NaN      NaN
# Arceus                       NaN      NaN
# Arceus Duraludon             NaN      NaN
# Arceus Flying Pikachu        NaN      NaN
# Arceus Giratina              NaN      NaN
# Arceus Goodra                0.5      NaN
# Arceus Mewtwo                NaN      NaN
# Arceus Rayquaza              NaN      NaN
# Blissey                      NaN      NaN
# Calyrex Inteleon             NaN      NaN
# Charizard                    NaN      NaN
# Cramorant                    NaN      NaN
# Crobat Weezing               NaN      NaN
# Dialga                       NaN      NaN
# Dialga Bronzong              NaN      NaN
# Dialga LZ                    NaN      NaN
# Durant                       NaN      NaN
# Eternatus                    NaN      NaN
# Flaaffy                      NaN      NaN
# Galarian Weezing             NaN      NaN
# Gengar                       NaN      NaN
# Giratina LZ Box              0.0      NaN
# Hisuian Goodra               0.5      NaN
# Hisuian Samurott             NaN      NaN
# Hisuian Zoroark              1.0      NaN
# Ice Rider Calyrex            NaN      NaN
# Inteleon Box                 NaN      NaN
# Kyurem                       NaN      NaN
# Kyurem Palkia                NaN      NaN
# Lost Zone Box                0.0      NaN
# Lunatone Solrock             NaN      NaN
# Machamp                      NaN      NaN
# Mew Genesect                 NaN      0.0
# Other                        NaN      NaN
# Palkia Inteleon              1.0      NaN
# Rapid Strike Urshifu         NaN      NaN
# Regis                        NaN      NaN
# Shadow Rider Calyrex         NaN      NaN
# Suicune Inteleon             NaN      NaN
# Urshifu Inteleon             NaN      NaN
# Vikavolt                     NaN      NaN
# Volcarona                    NaN      NaN
# Zeraora                      NaN      NaN
#
# [43 rows x 43 columns]

# %%
len(mu)
# Out:
# 43

# %%
# Find win rate for every deck in index (opposing deck)
mu = []
for deck in heatmap_df.index:
    if deck in filtered_df['opposing_deck'].unique():
        winrate = filtered_df[filtered_df['opposing_deck']==deck].iloc[0]['winrate']
        mu.append(winrate)
    else:
        winrate = None
        mu.append(winrate)

# %%
len(mu)
# Out:
# 43

# %%
heatmap_df['Palkia Inteleon'] = mu

# %%
heatmap_df
# Out:
#                       Arcanine Zoroark Arceus Arceus Duraludon  \
# Arcanine Zoroark                   NaN    NaN              NaN
# Arceus                             NaN    NaN              NaN
# Arceus Duraludon                   NaN    NaN              NaN
# Arceus Flying Pikachu              NaN    NaN              NaN
# Arceus Giratina                    NaN    NaN              NaN
# Arceus Goodra                      NaN    NaN              NaN
# Arceus Mewtwo                      NaN    NaN              NaN
# Arceus Rayquaza                    NaN    NaN              NaN
# Blissey                            NaN    NaN              NaN
# Calyrex Inteleon                   NaN    NaN              NaN
# Charizard                          NaN    NaN              NaN
# Cramorant                          NaN    NaN              NaN
# Crobat Weezing                     NaN    NaN              NaN
# Dialga                             NaN    NaN              NaN
# Dialga Bronzong                    NaN    NaN              NaN
# Dialga LZ                          NaN    NaN              NaN
# Durant                             NaN    NaN              NaN
# Eternatus                          NaN    NaN              NaN
# Flaaffy                            NaN    NaN              NaN
# Galarian Weezing                   NaN    NaN              NaN
# Gengar                             NaN    NaN              NaN
# Giratina LZ Box                    NaN    NaN              NaN
# Hisuian Goodra                     NaN    NaN              NaN
# Hisuian Samurott                   NaN    NaN              NaN
# Hisuian Zoroark                    NaN    NaN              NaN
# Ice Rider Calyrex                  NaN    NaN              NaN
# Inteleon Box                       NaN    NaN              NaN
# Kyurem                             NaN    NaN              NaN
# Kyurem Palkia                      NaN    NaN              NaN
# Lost Zone Box                      NaN    NaN              NaN
# Lunatone Solrock                   NaN    NaN              NaN
# Machamp                            NaN    NaN              NaN
# Mew Genesect                       NaN    NaN              NaN
# Other                              NaN    NaN              NaN
# Palkia Inteleon                    NaN    NaN              NaN
# Rapid Strike Urshifu               NaN    NaN              NaN
# Regis                              NaN    NaN              NaN
# Shadow Rider Calyrex               NaN    NaN              NaN
# Suicune Inteleon                   NaN    NaN              NaN
# Urshifu Inteleon                   NaN    NaN              NaN
# Vikavolt                           NaN    NaN              NaN
# Volcarona                          NaN    NaN              NaN
# Zeraora                            NaN    NaN              NaN
#
#                       Arceus Flying Pikachu Arceus Giratina Arceus Goodra  \
# Arcanine Zoroark                        NaN             NaN           NaN
# Arceus                                  NaN             NaN           NaN
# Arceus Duraludon                        NaN             NaN           NaN
# Arceus Flying Pikachu                   NaN             NaN           NaN
# Arceus Giratina                         NaN             NaN           NaN
# Arceus Goodra                           NaN             NaN           NaN
# Arceus Mewtwo                           NaN             NaN           NaN
# Arceus Rayquaza                         NaN             NaN           NaN
# Blissey                                 NaN             NaN           NaN
# Calyrex Inteleon                        NaN             NaN           NaN
# Charizard                               NaN             NaN           NaN
# Cramorant                               NaN             NaN           NaN
# Crobat Weezing                          NaN             NaN           NaN
# Dialga                                  NaN             NaN           NaN
# Dialga Bronzong                         NaN             NaN           NaN
# Dialga LZ                               NaN             NaN           NaN
# Durant                                  NaN             NaN           NaN
# Eternatus                               NaN             NaN           NaN
# Flaaffy                                 NaN             NaN           NaN
# Galarian Weezing                        NaN             NaN           NaN
# Gengar                                  NaN             NaN           NaN
# Giratina LZ Box                         NaN             NaN           NaN
# Hisuian Goodra                          NaN             NaN           NaN
# Hisuian Samurott                        NaN             NaN           NaN
# Hisuian Zoroark                         NaN             NaN           NaN
# Ice Rider Calyrex                       NaN             NaN           NaN
# Inteleon Box                            NaN             NaN           NaN
# Kyurem                                  NaN             NaN           NaN
# Kyurem Palkia                           NaN             NaN           NaN
# Lost Zone Box                           NaN             NaN           NaN
# Lunatone Solrock                        NaN             NaN           NaN
# Machamp                                 NaN             NaN           NaN
# Mew Genesect                            NaN             NaN           NaN
# Other                                   NaN             NaN           NaN
# Palkia Inteleon                         NaN             NaN           NaN
# Rapid Strike Urshifu                    NaN             NaN           NaN
# Regis                                   NaN             NaN           NaN
# Shadow Rider Calyrex                    NaN             NaN           NaN
# Suicune Inteleon                        NaN             NaN           NaN
# Urshifu Inteleon                        NaN             NaN           NaN
# Vikavolt                                NaN             NaN           NaN
# Volcarona                               NaN             NaN           NaN
# Zeraora                                 NaN             NaN           NaN
#
#                       Arceus Mewtwo Arceus Rayquaza Blissey Calyrex Inteleon  \
# Arcanine Zoroark                NaN             NaN     NaN              NaN
# Arceus                          NaN             NaN     NaN              NaN
# Arceus Duraludon                NaN             NaN     NaN              NaN
# Arceus Flying Pikachu           NaN             NaN     NaN              NaN
# Arceus Giratina                 NaN             NaN     NaN              NaN
# Arceus Goodra                   NaN             NaN     NaN              NaN
# Arceus Mewtwo                   NaN             NaN     NaN              NaN
# Arceus Rayquaza                 NaN             NaN     NaN              NaN
# Blissey                         NaN             NaN     NaN              NaN
# Calyrex Inteleon                NaN             NaN     NaN              NaN
# Charizard                       NaN             NaN     NaN              NaN
# Cramorant                       NaN             NaN     NaN              NaN
# Crobat Weezing                  NaN             NaN     NaN              NaN
# Dialga                          NaN             NaN     NaN              NaN
# Dialga Bronzong                 NaN             NaN     NaN              NaN
# Dialga LZ                       NaN             NaN     NaN              NaN
# Durant                          NaN             NaN     NaN              NaN
# Eternatus                       NaN             NaN     NaN              NaN
# Flaaffy                         NaN             NaN     NaN              NaN
# Galarian Weezing                NaN             NaN     NaN              NaN
# Gengar                          NaN             NaN     NaN              NaN
# Giratina LZ Box                 NaN             NaN     NaN              NaN
# Hisuian Goodra                  NaN             NaN     NaN              NaN
# Hisuian Samurott                NaN             NaN     NaN              NaN
# Hisuian Zoroark                 NaN             NaN     NaN              NaN
# Ice Rider Calyrex               NaN             NaN     NaN              NaN
# Inteleon Box                    NaN             NaN     NaN              NaN
# Kyurem                          NaN             NaN     NaN              NaN
# Kyurem Palkia                   NaN             NaN     NaN              NaN
# Lost Zone Box                   NaN             NaN     NaN              NaN
# Lunatone Solrock                NaN             NaN     NaN              NaN
# Machamp                         NaN             NaN     NaN              NaN
# Mew Genesect                    NaN             NaN     NaN              NaN
# Other                           NaN             NaN     NaN              NaN
# Palkia Inteleon                 NaN             NaN     NaN              NaN
# Rapid Strike Urshifu            NaN             NaN     NaN              NaN
# Regis                           NaN             NaN     NaN              NaN
# Shadow Rider Calyrex            NaN             NaN     NaN              NaN
# Suicune Inteleon                NaN             NaN     NaN              NaN
# Urshifu Inteleon                NaN             NaN     NaN              NaN
# Vikavolt                        NaN             NaN     NaN              NaN
# Volcarona                       NaN             NaN     NaN              NaN
# Zeraora                         NaN             NaN     NaN              NaN
#
#                        ... Other Palkia Inteleon Rapid Strike Urshifu Regis  \
# Arcanine Zoroark       ...   NaN            0.00                  NaN   NaN
# Arceus                 ...   NaN            0.75                  NaN   NaN
# Arceus Duraludon       ...   NaN            0.50                  NaN   NaN
# Arceus Flying Pikachu  ...   NaN            0.00                  NaN   NaN
# Arceus Giratina        ...   NaN            1.00                  NaN   NaN
# Arceus Goodra          ...   NaN            0.40                  NaN   NaN
# Arceus Mewtwo          ...   NaN            1.00                  NaN   NaN
# Arceus Rayquaza        ...   NaN             NaN                  NaN   NaN
# Blissey                ...   NaN            0.12                  NaN   NaN
# Calyrex Inteleon       ...   NaN             NaN                  NaN   NaN
# Charizard              ...   NaN             NaN                  NaN   NaN
# Cramorant              ...   NaN             NaN                  NaN   NaN
# Crobat Weezing         ...   NaN            1.00                  NaN   NaN
# Dialga                 ...   NaN            0.25                  NaN   NaN
# Dialga Bronzong        ...   NaN            1.00                  NaN   NaN
# Dialga LZ              ...   NaN            0.29                  NaN   NaN
# Durant                 ...   NaN            0.50                  NaN   NaN
# Eternatus              ...   NaN            0.75                  NaN   NaN
# Flaaffy                ...   NaN             NaN                  NaN   NaN
# Galarian Weezing       ...   NaN             NaN                  NaN   NaN
# Gengar                 ...   NaN            1.00                  NaN   NaN
# Giratina LZ Box        ...   NaN            0.50                  NaN   NaN
# Hisuian Goodra         ...   NaN            0.75                  NaN   NaN
# Hisuian Samurott       ...   NaN             NaN                  NaN   NaN
# Hisuian Zoroark        ...   NaN            0.60                  NaN   NaN
# Ice Rider Calyrex      ...   NaN             NaN                  NaN   NaN
# Inteleon Box           ...   NaN             NaN                  NaN   NaN
# Kyurem                 ...   NaN            1.00                  NaN   NaN
# Kyurem Palkia          ...   NaN            0.90                  NaN   NaN
# Lost Zone Box          ...   NaN            0.43                  NaN   NaN
# Lunatone Solrock       ...   NaN            1.00                  NaN   NaN
# Machamp                ...   NaN             NaN                  NaN   NaN
# Mew Genesect           ...   NaN            0.50                  NaN   NaN
# Other                  ...   NaN            1.00                  NaN   NaN
# Palkia Inteleon        ...   NaN            0.47                  NaN   NaN
# Rapid Strike Urshifu   ...   NaN            1.00                  NaN   NaN
# Regis                  ...   NaN            0.50                  NaN   NaN
# Shadow Rider Calyrex   ...   NaN            0.33                  NaN   NaN
# Suicune Inteleon       ...   NaN            1.00                  NaN   NaN
# Urshifu Inteleon       ...   NaN            1.00                  NaN   NaN
# Vikavolt               ...   NaN            0.60                  NaN   NaN
# Volcarona              ...   NaN            0.00                  NaN   NaN
# Zeraora                ...   NaN             NaN                  NaN   NaN
#
#                       Shadow Rider Calyrex Suicune Inteleon Urshifu Inteleon  \
# Arcanine Zoroark                       NaN              NaN              NaN
# Arceus                                 NaN              NaN              NaN
# Arceus Duraludon                       NaN              NaN              NaN
# Arceus Flying Pikachu                  NaN              NaN              NaN
# Arceus Giratina                        NaN              NaN              NaN
# Arceus Goodra                          NaN              NaN              NaN
# Arceus Mewtwo                          NaN              NaN              NaN
# Arceus Rayquaza                        NaN              NaN              NaN
# Blissey                                NaN              NaN              NaN
# Calyrex Inteleon                       NaN              NaN              NaN
# Charizard                              NaN              NaN              NaN
# Cramorant                              NaN              NaN              NaN
# Crobat Weezing                         NaN              NaN              NaN
# Dialga                                 NaN              NaN              NaN
# Dialga Bronzong                        NaN              NaN              NaN
# Dialga LZ                              NaN              NaN              NaN
# Durant                                 NaN              NaN              NaN
# Eternatus                              NaN              NaN              NaN
# Flaaffy                                NaN              NaN              NaN
# Galarian Weezing                       NaN              NaN              NaN
# Gengar                                 NaN              NaN              NaN
# Giratina LZ Box                        NaN              NaN              NaN
# Hisuian Goodra                         NaN              NaN              NaN
# Hisuian Samurott                       NaN              NaN              NaN
# Hisuian Zoroark                        NaN              NaN              NaN
# Ice Rider Calyrex                      NaN              NaN              NaN
# Inteleon Box                           NaN              NaN              NaN
# Kyurem                                 NaN              NaN              NaN
# Kyurem Palkia                          NaN              NaN              NaN
# Lost Zone Box                          NaN              NaN              NaN
# Lunatone Solrock                       NaN              NaN              NaN
# Machamp                                NaN              NaN              NaN
# Mew Genesect                           NaN              NaN              NaN
# Other                                  NaN              NaN              NaN
# Palkia Inteleon                        NaN              NaN              NaN
# Rapid Strike Urshifu                   NaN              NaN              NaN
# Regis                                  NaN              NaN              NaN
# Shadow Rider Calyrex                   NaN              NaN              NaN
# Suicune Inteleon                       NaN              NaN              NaN
# Urshifu Inteleon                       NaN              NaN              NaN
# Vikavolt                               NaN              NaN              NaN
# Volcarona                              NaN              NaN              NaN
# Zeraora                                NaN              NaN              NaN
#
#                       Vikavolt Volcarona Zeraora
# Arcanine Zoroark           NaN       NaN     NaN
# Arceus                     NaN       NaN     NaN
# Arceus Duraludon           NaN       NaN     NaN
# Arceus Flying Pikachu      NaN       NaN     NaN
# Arceus Giratina            NaN       NaN     NaN
# Arceus Goodra              NaN       NaN     NaN
# Arceus Mewtwo              NaN       NaN     NaN
# Arceus Rayquaza            NaN       NaN     NaN
# Blissey                    NaN       NaN     NaN
# Calyrex Inteleon           NaN       NaN     NaN
# Charizard                  NaN       NaN     NaN
# Cramorant                  NaN       NaN     NaN
# Crobat Weezing             NaN       NaN     NaN
# Dialga                     NaN       NaN     NaN
# Dialga Bronzong            NaN       NaN     NaN
# Dialga LZ                  NaN       NaN     NaN
# Durant                     NaN       NaN     NaN
# Eternatus                  NaN       NaN     NaN
# Flaaffy                    NaN       NaN     NaN
# Galarian Weezing           NaN       NaN     NaN
# Gengar                     NaN       NaN     NaN
# Giratina LZ Box            NaN       NaN     NaN
# Hisuian Goodra             NaN       NaN     NaN
# Hisuian Samurott           NaN       NaN     NaN
# Hisuian Zoroark            NaN       NaN     NaN
# Ice Rider Calyrex          NaN       NaN     NaN
# Inteleon Box               NaN       NaN     NaN
# Kyurem                     NaN       NaN     NaN
# Kyurem Palkia              NaN       NaN     NaN
# Lost Zone Box              NaN       NaN     NaN
# Lunatone Solrock           NaN       NaN     NaN
# Machamp                    NaN       NaN     NaN
# Mew Genesect               NaN       NaN     NaN
# Other                      NaN       NaN     NaN
# Palkia Inteleon            NaN       NaN     NaN
# Rapid Strike Urshifu       NaN       NaN     NaN
# Regis                      NaN       NaN     NaN
# Shadow Rider Calyrex       NaN       NaN     NaN
# Suicune Inteleon           NaN       NaN     NaN
# Urshifu Inteleon           NaN       NaN     NaN
# Vikavolt                   NaN       NaN     NaN
# Volcarona                  NaN       NaN     NaN
# Zeraora                    NaN       NaN     NaN
#
# [43 rows x 43 columns]

# %%
# 1. Filter data on active deck 
# 2. Filter data based on archetypes in opposing decks
# 3. Create a blank heatmap with columns/indices for each archetype in filtered dataset 
# 4. Group filtered dataframe to get mean win rate and total games played 
# 5. Get win rates by looping through list of columns 
# 6. Plot the heatmap 

# 1
active_deck = 'Palkia Inteleon'
opposing_decks = ["Palkia Inteleon", "Kyurem Palkia", "Lost Zone Box", "Giratina LZ Box", "Mew Genesect"]
opposing_decks.append(active_deck)
unique_decks = []
for deck in opposing_decks:
    if deck not in unique_decks:
        unique_decks.append(deck)

# 2
active_deck_df = plot_df[plot_df["deck"].isin(unique_decks)]
filtered_df = active_deck_df[active_deck_df["opposing_deck"].isin(unique_decks)]

# 3 
opposing_decks.append(active_deck)
unique_decks = []
for deck in opposing_decks:
    if deck not in unique_decks:
        unique_decks.append(deck)
        
# blank heatmaps for wins and games played
heatmap_gp = pd.DataFrame(columns=unique_decks, index=unique_decks)
heatmap_wr = pd.DataFrame(columns=unique_decks, index=unique_decks)

# Create aggregated df 
groupby_df = filtered_df.groupby(['deck', 'opposing_deck']).agg({"winrate": "mean", "games_played": "sum"}).reset_index()

# Iterate through each active deck
for active_deck in heatmap_wr:
    filtered_df = groupby_df[groupby_df['deck']==active_deck]
    
    # Find win rate for every deck in index (opposing deck)
    wr_ls = []
    gp_ls = []
    for deck in heatmap_wr.index:
        if deck in filtered_df['opposing_deck'].unique():
            winrate = filtered_df[filtered_df['opposing_deck']==deck].iloc[0]['winrate']
            gp = filtered_df[filtered_df['opposing_deck']==deck].iloc[0]['games_played']
            wr_ls.append(winrate)
            gp_ls.append(gp)
        else:
            winrate = None
            mu.append(winrate)
            gp_ls.append(None)
        
    # set column to mu 
    heatmap_wr[active_deck] = wr_ls
    heatmap_gp[active_deck] = gp_ls

# %%
# heatmap hovertext; active deck, opposing deck, win rate, games played
hovertext = []
for xi, xx in enumerate(heatmap_wr.columns):
    hovertext.append(list())
    for yi, yy in enumerate(heatmap_wr.index):
        hovertext[-1].append(f"Active Deck: {xx}<br />Opposing Deck: {yy}<br />Win Rate: {heatmap_wr.values[yi][xi]}<br />Games Played: {heatmap_gp.values[yi][xi]}")

# %%
# construct heatmap 
import plotly.graph_objects as go 
fig = go.Figure(data=go.Heatmap(
                   z=heatmap_wr.values,
                   x=heatmap_wr.columns.tolist(),
                   y=heatmap_wr.index.tolist(),
                   hoverinfo='text',
                   text=hovertext,
                   texttemplate="%{z}",
                   textfont={"size": 20},
                   hoverongaps = False,
                   xgap=3, 
                   ygap=3
))
fig.show()
# Out:
# <div>                            <div id="ab5739ca-e2b1-4ad5-9b0d-2bc54a6951f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab5739ca-e2b1-4ad5-9b0d-2bc54a6951f5")) {                    Plotly.newPlot(                        "ab5739ca-e2b1-4ad5-9b0d-2bc54a6951f5",                        [{"hoverinfo":"text","hoverongaps":false,"text":[["Active Deck: Palkia Inteleon<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.47<br />Games Played: 34","Active Deck: Palkia Inteleon<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.9<br />Games Played: 10","Active Deck: Palkia Inteleon<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.43<br />Games Played: 14","Active Deck: Palkia Inteleon<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.5<br />Games Played: 38","Active Deck: Palkia Inteleon<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.5<br />Games Played: 18"],["Active Deck: Kyurem Palkia<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.1<br />Games Played: 10","Active Deck: Kyurem Palkia<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.5<br />Games Played: 12","Active Deck: Kyurem Palkia<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.48<br />Games Played: 25","Active Deck: Kyurem Palkia<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.53<br />Games Played: 19","Active Deck: Kyurem Palkia<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.47<br />Games Played: 19"],["Active Deck: Lost Zone Box<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.57<br />Games Played: 14","Active Deck: Lost Zone Box<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.48<br />Games Played: 25","Active Deck: Lost Zone Box<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.48<br />Games Played: 46","Active Deck: Lost Zone Box<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.53<br />Games Played: 36","Active Deck: Lost Zone Box<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.44<br />Games Played: 25"],["Active Deck: Giratina LZ Box<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.5<br />Games Played: 38","Active Deck: Giratina LZ Box<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.42<br />Games Played: 19","Active Deck: Giratina LZ Box<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.42<br />Games Played: 36","Active Deck: Giratina LZ Box<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.47<br />Games Played: 106","Active Deck: Giratina LZ Box<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.58<br />Games Played: 43"],["Active Deck: Mew Genesect<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.5<br />Games Played: 18","Active Deck: Mew Genesect<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.47<br />Games Played: 19","Active Deck: Mew Genesect<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.52<br />Games Played: 25","Active Deck: Mew Genesect<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.37<br />Games Played: 43","Active Deck: Mew Genesect<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.48<br />Games Played: 58"]],"textfont":{"size":20},"texttemplate":"%{z}","x":["Palkia Inteleon","Kyurem Palkia","Lost Zone Box","Giratina LZ Box","Mew Genesect"],"xgap":3,"y":["Palkia Inteleon","Kyurem Palkia","Lost Zone Box","Giratina LZ Box","Mew Genesect"],"ygap":3,"z":[[0.47,0.1,0.57,0.5,0.5],[0.9,0.5,0.48,0.42,0.47],[0.43,0.48,0.48,0.42,0.52],[0.5,0.53,0.53,0.47,0.37],[0.5,0.47,0.44,0.58,0.48]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %%
heatmap_wr
# Out:
#                  Palkia Inteleon  Kyurem Palkia  Lost Zone Box  \
# Palkia Inteleon             0.47           0.10           0.57
# Kyurem Palkia               0.90           0.50           0.48
# Lost Zone Box               0.43           0.48           0.48
# Giratina LZ Box             0.50           0.53           0.53
# Mew Genesect                0.50           0.47           0.44
#
#                  Giratina LZ Box  Mew Genesect
# Palkia Inteleon             0.50          0.50
# Kyurem Palkia               0.42          0.47
# Lost Zone Box               0.42          0.52
# Giratina LZ Box             0.47          0.37
# Mew Genesect                0.58          0.48

# %%
heatmap_wr.values
# Out:
# array([[0.47, 0.1 , 0.57, 0.5 , 0.5 ],
#        [0.9 , 0.5 , 0.48, 0.42, 0.47],
#        [0.43, 0.48, 0.48, 0.42, 0.52],
#        [0.5 , 0.53, 0.53, 0.47, 0.37],
#        [0.5 , 0.47, 0.44, 0.58, 0.48]])

# %%
plot_df[(plot_df['deck']=="Palkia Inteleon") & (plot_df['opposing_deck']=="Kyurem Palkia")]
# Out:
#                 deck  opposing_deck  \
# 124  Palkia Inteleon  Kyurem Palkia
#
#                                               t_url        date  winrate  \
# 124  https://play.limitlesstcg.com/tournament/ln68/  2022-11-01      0.9
#
#      games_played
# 124            10

# %%
test = list()

# %%
for xi,xx in enumerate(range(10)):
    test.append(list())
    for yi, yy in enumerate(range(10)):
        test[-1].append(f"{xi, yi}")

# %%
hovertext = []
for xi, xx in enumerate(heatmap_wr.columns):
    hovertext.append(list())
    for yi, yy in enumerate(heatmap_wr.index):
        hovertext[-1].append(f"Active Deck: {xx}<br />Opposing Deck: {yy}<br />Win Rate: {heatmap_wr.values[yi][xi]}<br />Games Played: {heatmap_gp.values[yi][xi]}")

# %%
hovertext
# Out:
# [['Active Deck: Palkia Inteleon<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.47<br />Games Played: 34',
#   'Active Deck: Palkia Inteleon<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.9<br />Games Played: 10',
#   'Active Deck: Palkia Inteleon<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.43<br />Games Played: 14',
#   'Active Deck: Palkia Inteleon<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.5<br />Games Played: 38',
#   'Active Deck: Palkia Inteleon<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.5<br />Games Played: 18'],
#  ['Active Deck: Kyurem Palkia<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.1<br />Games Played: 10',
#   'Active Deck: Kyurem Palkia<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.5<br />Games Played: 12',
#   'Active Deck: Kyurem Palkia<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.48<br />Games Played: 25',
#   'Active Deck: Kyurem Palkia<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.53<br />Games Played: 19',
#   'Active Deck: Kyurem Palkia<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.47<br />Games Played: 19'],
#  ['Active Deck: Lost Zone Box<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.57<br />Games Played: 14',
#   'Active Deck: Lost Zone Box<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.48<br />Games Played: 25',
#   'Active Deck: Lost Zone Box<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.48<br />Games Played: 46',
#   'Active Deck: Lost Zone Box<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.53<br />Games Played: 36',
#   'Active Deck: Lost Zone Box<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.44<br />Games Played: 25'],
#  ['Active Deck: Giratina LZ Box<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.5<br />Games Played: 38',
#   'Active Deck: Giratina LZ Box<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.42<br />Games Played: 19',
#   'Active Deck: Giratina LZ Box<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.42<br />Games Played: 36',
#   'Active Deck: Giratina LZ Box<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.47<br />Games Played: 106',
#   'Active Deck: Giratina LZ Box<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.58<br />Games Played: 43'],
#  ['Active Deck: Mew Genesect<br />Opposing Deck: Palkia Inteleon<br />Win Rate: 0.5<br />Games Played: 18',
#   'Active Deck: Mew Genesect<br />Opposing Deck: Kyurem Palkia<br />Win Rate: 0.47<br />Games Played: 19',
#   'Active Deck: Mew Genesect<br />Opposing Deck: Lost Zone Box<br />Win Rate: 0.52<br />Games Played: 25',
#   'Active Deck: Mew Genesect<br />Opposing Deck: Giratina LZ Box<br />Win Rate: 0.37<br />Games Played: 43',
#   'Active Deck: Mew Genesect<br />Opposing Deck: Mew Genesect<br />Win Rate: 0.48<br />Games Played: 58']]

# %%
heatmap_wr.values
# Out:
# array([[0.47, 0.1 , 0.57, 0.5 , 0.5 ],
#        [0.9 , 0.5 , 0.48, 0.42, 0.47],
#        [0.43, 0.48, 0.48, 0.42, 0.52],
#        [0.5 , 0.53, 0.53, 0.47, 0.37],
#        [0.5 , 0.47, 0.44, 0.58, 0.48]])
